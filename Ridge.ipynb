# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("BostonHousing.csv")

# %%
df = df.dropna()

# %%
x = df.drop("MEDV", axis = 1)
y = df["MEDV"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=42)

# %%
model = Ridge(alpha=1.0)
model.fit(x_train, y_train)
# Out:
# Ridge()

# %%
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# %%
print("MSE:", mse)
print("RMSE: ", rmse)
print("R2: ", r2)
print("Coefficient: ", model.coef_)
# Out:
# MSE: 31.992394845754593
# RMSE:  5.656182002530912
# R2:  0.6207024215900819
# Coefficient:  [-0.1080254   0.04382929 -0.01331072  1.81801893 -8.33556772  4.32712491
#  -0.02936646 -1.29395108  0.20153627 -0.01201576 -0.88521235  0.00997504
#  -0.39540151]

# %%
plt.scatter(y_test, y_pred, alpha = 0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], "r--")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
