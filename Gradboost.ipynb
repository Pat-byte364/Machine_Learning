# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("AmesHousing.csv")

# %%
cols = ["Lot Area", "Overall Qual", "Overall Cond", "Year Built", "Gr Liv Area", "Total Bsmt SF", "Garage Cars", "SalePrice"]
df = df[cols]
df = df.dropna()

# %%
x = df.drop(columns=["SalePrice"])
y = df["SalePrice"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = GradientBoostingRegressor(n_estimators = 100, learning_rate = 0.1, random_state = 42)
model.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# %%
print("MSE:", mse)
print("RMSE:", rmse)
print("R2:", r2)
# Out:
# MSE: 647275429.9484
# RMSE: 25441.60824217683
# R2: 0.9212675784426613

# %%
plt.scatter(y_test, y_pred, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted - Gradient Boosting")
plt.show()

# %%
importances = model.feature_importances_
feat_names = x.columns
sorted_idx = np.argsort(importances)[::-1]

plt.figure(figsize=(8,5))
plt.bar(range(len(importances)), importances[sorted_idx])
plt.xticks(range(len(importances)), feat_names[sorted_idx], rotation=45, ha='right')
plt.ylabel("Importance")
plt.title("Feature Importance - Gradient Boosting")
plt.tight_layout()
plt.show()
